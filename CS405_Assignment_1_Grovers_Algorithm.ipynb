# %% [markdown]
# # CS405 Assignment 1
#
# ## Grover's Algorithm
#
# In this assignment, you will implement Grover's search algorithm.
#
# ### Instructions
#
# 1. Read the papers on Grover's search algorithm.
# 2. Implement the algorithm in Python.
# 3. Test your implementation with different cases.
# 4. Write a brief report on your findings and submit it along with your code.

# %%
# Student Implementation

# Your code goes here...
